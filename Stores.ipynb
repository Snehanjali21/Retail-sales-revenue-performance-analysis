# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\Snehanjali\Downloads\Stores.csv', encoding='latin1')

# %%
df
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2019-160304  01-01-2019  07-01-2019  Standard Class    BM-11575
# 1     CA-2019-160304  02-01-2019  07-01-2019  Standard Class    BM-11575
# 2     CA-2019-160304  02-01-2019  07-01-2019  Standard Class    BM-11575
# 3     CA-2019-125206  03-01-2019  05-01-2019     First Class    LR-16915
# 4     US-2019-116365  03-01-2019  08-01-2019  Standard Class    CA-12310
# ...              ...         ...         ...             ...         ...
# 5896  CA-2020-143259  30-12-2020  03-01-2021  Standard Class    PO-18865
# 5897  CA-2020-115427  30-12-2020  03-01-2021  Standard Class    EB-13975
# 5898  CA-2020-156720  30-12-2020  03-01-2021  Standard Class    JM-15580
# 5899  CA-2020-143259  30-12-2020  03-01-2021  Standard Class    PO-18865
# 5900  CA-2020-151450  31-12-2020  04-01-2021  Standard Class    JM-15580
#
#           Customer Name    Segment        Country           City       State  \
# 0         Brendan Murry  Corporate  United States   Gaithersburg    Maryland
# 1         Brendan Murry  Corporate  United States   Gaithersburg    Maryland
# 2         Brendan Murry  Corporate  United States   Gaithersburg    Maryland
# 3          Lena Radford   Consumer  United States    Los Angeles  California
# 4     Christine Abelman  Corporate  United States    San Antonio       Texas
# ...                 ...        ...            ...            ...         ...
# 5896  Patrick O'Donnell   Consumer  United States  New York City    New York
# 5897         Erica Bern  Corporate  United States      Fairfield  California
# 5898      Jill Matthias   Consumer  United States       Loveland    Colorado
# 5899  Patrick O'Donnell   Consumer  United States  New York City    New York
# 5900      Jill Matthias   Consumer  United States       Loveland    Colorado
#
#       ...         Category Sub-Category  \
# 0     ...        Furniture    Bookcases
# 1     ...        Furniture    Bookcases
# 2     ...       Technology       Phones
# 3     ...  Office Supplies      Storage
# 4     ...       Technology  Accessories
# ...   ...              ...          ...
# 5896  ...        Furniture    Bookcases
# 5897  ...  Office Supplies      Binders
# 5898  ...  Office Supplies    Fasteners
# 5899  ...  Office Supplies      Binders
# 5900  ...  Office Supplies    Fasteners
#
#                                            Product Name     Sales Quantity  \
# 0     Bush Westfield Collection Bookcases, Medium Ch...    73.940        1
# 1     Bush Westfield Collection Bookcases, Medium Ch...   173.940        3
# 2                                           GE 30522EE2   231.980        2
# 3     Recycled Steel Personal File for Hanging File ...   114.460        2
# 4                   Imation Clip USB flash drive - 8 GB    30.080        2
# ...                                                 ...       ...      ...
# 5896  Bush Westfield Collection Bookcases, Fully Ass...   213.136        4
# 5897    Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl   295.904        2
# 5898                                Bagged Rubber Bands   388.024        3
# 5899               Wilson Jones Legal Size Ring Binders   462.776        3
# 5900                                Bagged Rubber Bands  2975.510        3
#
#        Profit  Returns  Payment Mode  ind1 ind2
# 0     28.2668      NaN        Online   NaN  NaN
# 1     38.2668      NaN        Online   NaN  NaN
# 2     67.2742      NaN         Cards   NaN  NaN
# 3     28.6150      NaN        Online   NaN  NaN
# 4     -5.2640      NaN        Online   NaN  NaN
# ...       ...      ...           ...   ...  ...
# 5896  12.1176      NaN           COD   NaN  NaN
# 5897   4.5188      1.0        Online   NaN  NaN
# 5898  -0.6048      NaN        Online   NaN  NaN
# 5899  19.7910      NaN           COD   NaN  NaN
# 5900  -0.6048      NaN           COD   NaN  NaN
#
# [5901 rows x 22 columns]

# %%
df.head(5)
# Out:
#          Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2019-160304  01-01-2019  07-01-2019  Standard Class    BM-11575
# 1  CA-2019-160304  02-01-2019  07-01-2019  Standard Class    BM-11575
# 2  CA-2019-160304  02-01-2019  07-01-2019  Standard Class    BM-11575
# 3  CA-2019-125206  03-01-2019  05-01-2019     First Class    LR-16915
# 4  US-2019-116365  03-01-2019  08-01-2019  Standard Class    CA-12310
#
#        Customer Name    Segment        Country          City       State  ...  \
# 0      Brendan Murry  Corporate  United States  Gaithersburg    Maryland  ...
# 1      Brendan Murry  Corporate  United States  Gaithersburg    Maryland  ...
# 2      Brendan Murry  Corporate  United States  Gaithersburg    Maryland  ...
# 3       Lena Radford   Consumer  United States   Los Angeles  California  ...
# 4  Christine Abelman  Corporate  United States   San Antonio       Texas  ...
#
#           Category Sub-Category  \
# 0        Furniture    Bookcases
# 1        Furniture    Bookcases
# 2       Technology       Phones
# 3  Office Supplies      Storage
# 4       Technology  Accessories
#
#                                         Product Name   Sales Quantity  \
# 0  Bush Westfield Collection Bookcases, Medium Ch...   73.94        1
# 1  Bush Westfield Collection Bookcases, Medium Ch...  173.94        3
# 2                                        GE 30522EE2  231.98        2
# 3  Recycled Steel Personal File for Hanging File ...  114.46        2
# 4                Imation Clip USB flash drive - 8 GB   30.08        2
#
#     Profit  Returns  Payment Mode  ind1 ind2
# 0  28.2668      NaN        Online   NaN  NaN
# 1  38.2668      NaN        Online   NaN  NaN
# 2  67.2742      NaN         Cards   NaN  NaN
# 3  28.6150      NaN        Online   NaN  NaN
# 4  -5.2640      NaN        Online   NaN  NaN
#
# [5 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# Order ID            0
# Order Date          0
# Ship Date           0
# Ship Mode           0
# Customer ID         0
# Customer Name       0
# Segment             0
# Country             0
# City                0
# State               0
# Region              0
# Product ID          0
# Category            0
# Sub-Category        0
# Product Name        0
# Sales               0
# Quantity            0
# Profit              0
# Returns          5614
# Payment Mode        0
# ind1             5901
# ind2             5901
# dtype: int64

# %%
df.shape
# Out:
# (5901, 22)

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Region',
#        'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales',
#        'Quantity', 'Profit', 'Returns', 'Payment Mode', 'ind1', 'ind2'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5901 entries, 0 to 5900
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       5901 non-null   object
#  1   Order Date     5901 non-null   object
#  2   Ship Date      5901 non-null   object
#  3   Ship Mode      5901 non-null   object
#  4   Customer ID    5901 non-null   object
#  5   Customer Name  5901 non-null   object
#  6   Segment        5901 non-null   object
#  7   Country        5901 non-null   object
#  8   City           5901 non-null   object
#  9   State          5901 non-null   object
#  10  Region         5901 non-null   object
#  11  Product ID     5901 non-null   object
#  12  Category       5901 non-null   object
#  13  Sub-Category   5901 non-null   object
#  14  Product Name   5901 non-null   object
#  15  Sales          5901 non-null   float64
#  16  Quantity       5901 non-null   int64
#  17  Profit         5901 non-null   float64
#  18  Returns        287 non-null    float64
#  19  Payment Mode   5901 non-null   object
#  20  ind1           0 non-null      float64
#  21  ind2           0 non-null      float64
# dtypes: float64(5), int64(1), object(16)
# memory usage: 1014.4+ KB

# %%
df.drop(columns=['ind1','ind2'])
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2019-160304  01-01-2019  07-01-2019  Standard Class    BM-11575
# 1     CA-2019-160304  02-01-2019  07-01-2019  Standard Class    BM-11575
# 2     CA-2019-160304  02-01-2019  07-01-2019  Standard Class    BM-11575
# 3     CA-2019-125206  03-01-2019  05-01-2019     First Class    LR-16915
# 4     US-2019-116365  03-01-2019  08-01-2019  Standard Class    CA-12310
# ...              ...         ...         ...             ...         ...
# 5896  CA-2020-143259  30-12-2020  03-01-2021  Standard Class    PO-18865
# 5897  CA-2020-115427  30-12-2020  03-01-2021  Standard Class    EB-13975
# 5898  CA-2020-156720  30-12-2020  03-01-2021  Standard Class    JM-15580
# 5899  CA-2020-143259  30-12-2020  03-01-2021  Standard Class    PO-18865
# 5900  CA-2020-151450  31-12-2020  04-01-2021  Standard Class    JM-15580
#
#           Customer Name    Segment        Country           City       State  \
# 0         Brendan Murry  Corporate  United States   Gaithersburg    Maryland
# 1         Brendan Murry  Corporate  United States   Gaithersburg    Maryland
# 2         Brendan Murry  Corporate  United States   Gaithersburg    Maryland
# 3          Lena Radford   Consumer  United States    Los Angeles  California
# 4     Christine Abelman  Corporate  United States    San Antonio       Texas
# ...                 ...        ...            ...            ...         ...
# 5896  Patrick O'Donnell   Consumer  United States  New York City    New York
# 5897         Erica Bern  Corporate  United States      Fairfield  California
# 5898      Jill Matthias   Consumer  United States       Loveland    Colorado
# 5899  Patrick O'Donnell   Consumer  United States  New York City    New York
# 5900      Jill Matthias   Consumer  United States       Loveland    Colorado
#
#        Region       Product ID         Category Sub-Category  \
# 0        East  FUR-BO-10004709        Furniture    Bookcases
# 1        East  FUR-BO-10004709        Furniture    Bookcases
# 2        East  TEC-PH-10000455       Technology       Phones
# 3        West  OFF-ST-10003692  Office Supplies      Storage
# 4     Central  TEC-AC-10002217       Technology  Accessories
# ...       ...              ...              ...          ...
# 5896     East  FUR-BO-10003441        Furniture    Bookcases
# 5897     West  OFF-BI-10002103  Office Supplies      Binders
# 5898     West  OFF-FA-10003472  Office Supplies    Fasteners
# 5899     East  OFF-BI-10003684  Office Supplies      Binders
# 5900     West  OFF-FA-10003472  Office Supplies    Fasteners
#
#                                            Product Name     Sales  Quantity  \
# 0     Bush Westfield Collection Bookcases, Medium Ch...    73.940         1
# 1     Bush Westfield Collection Bookcases, Medium Ch...   173.940         3
# 2                                           GE 30522EE2   231.980         2
# 3     Recycled Steel Personal File for Hanging File ...   114.460         2
# 4                   Imation Clip USB flash drive - 8 GB    30.080         2
# ...                                                 ...       ...       ...
# 5896  Bush Westfield Collection Bookcases, Fully Ass...   213.136         4
# 5897    Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl   295.904         2
# 5898                                Bagged Rubber Bands   388.024         3
# 5899               Wilson Jones Legal Size Ring Binders   462.776         3
# 5900                                Bagged Rubber Bands  2975.510         3
#
#        Profit  Returns Payment Mode
# 0     28.2668      NaN       Online
# 1     38.2668      NaN       Online
# 2     67.2742      NaN        Cards
# 3     28.6150      NaN       Online
# 4     -5.2640      NaN       Online
# ...       ...      ...          ...
# 5896  12.1176      NaN          COD
# 5897   4.5188      1.0       Online
# 5898  -0.6048      NaN       Online
# 5899  19.7910      NaN          COD
# 5900  -0.6048      NaN          COD
#
# [5901 rows x 20 columns]

# %%
total_sales= df['Sales'].sum()

# %%
total_sales
# Out:
# 1565804.3232

# %%
total_profit=df['Profit'].sum()

# %%
total_profit
# Out:
# 175262.1059

# %%
total_quantity= df['Quantity'].sum()

# %%
total_quantity
# Out:
# 22317

# %%
df['Order ID'].nunique()
# Out:
# 3003

# %%
df.groupby('Category')['Sales'].sum().sort_values(ascending=False)
# Out:
# Category
# Office Supplies    643707.6870
# Technology         470587.9910
# Furniture          451508.6452
# Name: Sales, dtype: float64

# %%
products=df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)
products
# Out:
# Product Name
# 3D Systems Cube Printer, 2nd Generation, Magenta                               14334.890
# Canon imageCLASS 2200 Advanced Copier                                          14076.824
# Hewlett Packard LaserJet 3310 Copier                                           13837.732
# GBC DocuBind TL300 Electric Binding System                                     12890.258
# GBC DocuBind P400 Electric Binding System                                      12577.108
# Samsung Galaxy Mega 6.3                                                        12370.708
# Martin Yale Chadless Opener Electric Letter Opener                             12268.902
# HON 5400 Series Task Chairs for Big and Tall                                   11887.562
# Global Troy Executive Leather Low-Back Tilter                                  10217.894
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind     9756.524
# Name: Sales, dtype: float64

# %%
date=pd.to_datetime(df['Order Date'], dayfirst=True)
date
# Out:
# 0      2019-01-01
# 1      2019-01-02
# 2      2019-01-02
# 3      2019-01-03
# 4      2019-01-03
#           ...
# 5896   2020-12-30
# 5897   2020-12-30
# 5898   2020-12-30
# 5899   2020-12-30
# 5900   2020-12-31
# Name: Order Date, Length: 5901, dtype: datetime64[ns]

# %%
df['Order Date'].dtype
# Out:
# dtype('O')

# %%
df['Order Date'] = pd.to_datetime(
    df['Order Date'],
    dayfirst=True,
    errors='coerce'
)

# %%
df['Order Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['YearMonth'] = df['Order Date'].dt.to_period('M')

# %%
df['YearMonth']
# Out:
# 0       2019-01
# 1       2019-01
# 2       2019-01
# 3       2019-01
# 4       2019-01
#          ...
# 5896    2020-12
# 5897    2020-12
# 5898    2020-12
# 5899    2020-12
# 5900    2020-12
# Name: YearMonth, Length: 5901, dtype: period[M]

# %%
monthly_sales = df.groupby('YearMonth')['Sales'].sum()
monthly_sales
# Out:
# YearMonth
# 2019-01     18616.4310
# 2019-02     19978.8150
# 2019-03     51715.8750
# 2019-04     38750.0390
# 2019-05     50987.7280
# 2019-06     40344.5340
# 2019-07     39261.9630
# 2019-08     31115.3743
# 2019-09     73410.0249
# 2019-10     42687.7450
# 2019-11     79411.9658
# 2019-12     78399.0430
# 2020-01     54763.3740
# 2020-02     52068.1334
# 2020-03     64229.3528
# 2020-04     50807.5361
# 2020-05     66750.1102
# 2020-06     69242.7257
# 2020-07     60077.4160
# 2020-08     77338.8880
# 2020-09    119803.6520
# 2020-10     88896.9232
# 2020-11    130960.8250
# 2020-12    166185.8488
# Freq: M, Name: Sales, dtype: float64

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

df['Year'] = df['Order Date'].dt.year
df['Month'] = df['Order Date'].dt.month
df['Month_Name'] = df['Order Date'].dt.month_name()

# %%
monthly_sales = df.groupby(['Year', 'Month_Name'])['Sales'].sum().reset_index()
monthly_sales
# Out:
#     Year Month_Name        Sales
# 0   2019      April   38750.0390
# 1   2019     August   31115.3743
# 2   2019   December   78399.0430
# 3   2019   February   19978.8150
# 4   2019    January   18616.4310
# 5   2019       July   39261.9630
# 6   2019       June   40344.5340
# 7   2019      March   51715.8750
# 8   2019        May   50987.7280
# 9   2019   November   79411.9658
# 10  2019    October   42687.7450
# 11  2019  September   73410.0249
# 12  2020      April   50807.5361
# 13  2020     August   77338.8880
# 14  2020   December  166185.8488
# 15  2020   February   52068.1334
# 16  2020    January   54763.3740
# 17  2020       July   60077.4160
# 18  2020       June   69242.7257
# 19  2020      March   64229.3528
# 20  2020        May   66750.1102
# 21  2020   November  130960.8250
# 22  2020    October   88896.9232
# 23  2020  September  119803.6520

# %%
yearly_sales = df.groupby('Year')['Sales'].sum().reset_index()
yearly_sales
# Out:
#    Year         Sales
# 0  2019  5.646795e+05
# 1  2020  1.001125e+06

# %%
sns.barplot['Category']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 sns.barplot['Category']
#
# TypeError: 'function' object is not subscriptable

# %%
df['Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
import matplotlib.pyplot as plt

category_sales = df.groupby('Category')['Sales'].sum().sort_values(ascending=False)

category_sales.plot(kind='bar')
plt.title('Category-wise Sales')
plt.xlabel('Category')
plt.ylabel('Total Sales')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 6
#       3 category_sales = df.groupby('Category')['Sales'].sum().sort_values(ascending=False)
#       5 category_sales.plot(kind='bar')
# ----> 6 plt.title('Category-wise Sales')
#       7 plt.xlabel('Category')
#       8 plt.ylabel('Total Sales')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'title'

# %%
top_products = (
    df.groupby('Product Name')['Sales']
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

top_products.plot(kind='bar')
plt.title('Top 10 Products by Sales')
plt.xlabel('Product')
plt.ylabel('Total Sales')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 9
#       1 top_products = (
#       2     df.groupby('Product Name')['Sales']
#       3     .sum()
#       4     .sort_values(ascending=False)
#       5     .head(10)
#       6 )
#       8 top_products.plot(kind='bar')
# ----> 9 plt.title('Top 10 Products by Sales')
#      10 plt.xlabel('Product')
#      11 plt.ylabel('Total Sales')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'title'

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Month'] = df['Order Date'].dt.to_period('M')

monthly_sales = df.groupby('Month')['Sales'].sum()

monthly_sales.plot(kind='line')
plt.title('Month-wise Sales Trend')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 7
#       4 monthly_sales = df.groupby('Month')['Sales'].sum()
#       6 monthly_sales.plot(kind='line')
# ----> 7 plt.title('Month-wise Sales Trend')
#       8 plt.xlabel('Month')
#       9 plt.ylabel('Total Sales')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'title'

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Month'] = df['Order Date'].dt.to_period('M')

monthly_sales = df.groupby('Month')['Sales'].sum()

monthly_sales.plot(kind='line')
plt.title('Month-wise Sales Trend')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 7
#       4 monthly_sales = df.groupby('Month')['Sales'].sum()
#       6 monthly_sales.plot(kind='line')
# ----> 7 plt.title('Month-wise Sales Trend')
#       8 plt.xlabel('Month')
#       9 plt.ylabel('Total Sales')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'title'

# %%
plt.scatter(df['Sales'], df['Profit'])
plt.title('Sales vs Profit')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 2
#       1 plt.scatter(df['Sales'], df['Profit'])
# ----> 2 plt.title('Sales vs Profit')
#       3 plt.xlabel('Sales')
#       4 plt.ylabel('Profit')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'title'

# %%
loss_products = (
    df.groupby('Product Name')['Profit']
    .sum()
    .sort_values()
    .head(10)
)

loss_products.plot(kind='bar')
plt.title('Top Loss-Making Products')
plt.xlabel('Product')
plt.ylabel('Total Loss')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 9
#       1 loss_products = (
#       2     df.groupby('Product Name')['Profit']
#       3     .sum()
#       4     .sort_values()
#       5     .head(10)
#       6 )
#       8 loss_products.plot(kind='bar')
# ----> 9 plt.title('Top Loss-Making Products')
#      10 plt.xlabel('Product')
#      11 plt.ylabel('Total Loss')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'title'
# C:\Users\Snehanjali\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 147 (\x93) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\Snehanjali\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 148 (\x94) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\Snehanjali\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 147 (\x93) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Snehanjali\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 148 (\x94) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.boxplot(df['Sales'])
plt.title('Sales Outlier Detection')
plt.ylabel('Sales')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 2
#       1 plt.boxplot(df['Sales'])
# ----> 2 plt.title('Sales Outlier Detection')
#       3 plt.ylabel('Sales')
#       4 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'title'

# %%
mean_sales = df['Sales'].mean()
median_sales = df['Sales'].median()
std_sales = df['Sales'].std()

mean_sales, median_sales, std_sales
# Out:
# (265.3455894255211, 128.648, 474.260645476471)

# %%
Q1 = df['Sales'].quantile(0.25)
Q3 = df['Sales'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['Sales'] < lower_bound) | (df['Sales'] > upper_bound)]
outliers
# Out:
#             Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 7     CA-2019-105207 2019-01-03  08-01-2019  Standard Class    BO-11350
# 9     US-2019-164630 2019-01-04  09-01-2019  Standard Class    EB-13975
# 18    US-2019-100461 2019-01-08  12-01-2019  Standard Class    JO-15145
# 50    US-2019-167339 2019-01-21  23-01-2019    Second Class    TD-20995
# 65    US-2019-165505 2019-01-23  27-01-2019  Standard Class    CB-12535
# ...              ...        ...         ...             ...         ...
# 5856  CA-2020-121741 2020-12-26  26-12-2020        Same Day    YC-21895
# 5860  CA-2020-134404 2020-12-27  27-12-2020        Same Day    DR-12880
# 5861  CA-2020-134404 2020-12-27  27-12-2020        Same Day    DR-12880
# 5875  CA-2020-163860 2020-12-28  01-01-2021  Standard Class    LO-17170
# 5900  CA-2020-151450 2020-12-31  04-01-2021  Standard Class    JM-15580
#
#          Customer Name    Segment        Country          City  \
# 7        Bill Overfelt  Corporate  United States  Broken Arrow
# 9           Erica Bern  Corporate  United States     Charlotte
# 18       Jack O'Briant  Corporate  United States      Franklin
# 50       Tamara Dahlen   Consumer  United States     San Diego
# 65    Claudia Bergmann  Corporate  United States    Burlington
# ...                ...        ...            ...           ...
# 5856    Yoseph Carroll  Corporate  United States       Fremont
# 5860   Dan Reichenbach  Corporate  United States        Newark
# 5861   Dan Reichenbach  Corporate  United States        Newark
# 5875        Lori Olson  Corporate  United States        Peoria
# 5900     Jill Matthias   Consumer  United States      Loveland
#
#                State  ... Quantity    Profit Returns Payment Mode ind1  ind2  \
# 7           Oklahoma  ...        7  350.4270     NaN          COD  NaN   NaN
# 9     North Carolina  ...        4  119.9960     NaN       Online  NaN   NaN
# 18         Wisconsin  ...        6  407.1288     NaN       Online  NaN   NaN
# 50        California  ...        7   76.0116     NaN          COD  NaN   NaN
# 65           Vermont  ...       13  406.7154     NaN       Online  NaN   NaN
# ...              ...  ...      ...       ...     ...          ...  ...   ...
# 5856        Nebraska  ...        2   37.5340     NaN       Online  NaN   NaN
# 5860            Ohio  ...        2  -35.6174     NaN          COD  NaN   NaN
# 5861            Ohio  ...        4    3.6432     NaN       Online  NaN   NaN
# 5875        Illinois  ...        3   -2.3904     NaN       Online  NaN   NaN
# 5900        Colorado  ...        3   -0.6048     NaN          COD  NaN   NaN
#
#       YearMonth  Year    Month Month_Name
# 7       2019-01  2019  2019-01    January
# 9       2019-01  2019  2019-01    January
# 18      2019-01  2019  2019-01    January
# 50      2019-01  2019  2019-01    January
# 65      2019-01  2019  2019-01    January
# ...         ...   ...      ...        ...
# 5856    2020-12  2020  2020-12   December
# 5860    2020-12  2020  2020-12   December
# 5861    2020-12  2020  2020-12   December
# 5875    2020-12  2020  2020-12   December
# 5900    2020-12  2020  2020-12   December
#
# [631 rows x 26 columns]

# %%
avg_sales_by_category = (
    df[df['Category'].isin(['Furniture', 'Technology'])]
    .groupby('Category')['Sales']
    .mean()
)

avg_sales_by_category
# Out:
# Category
# Furniture     361.496113
# Technology    434.522614
# Name: Sales, dtype: float64

# %%
correlation = df['Sales'].corr(df['Profit'])
correlation
# Out:
# 0.32591493036341135
